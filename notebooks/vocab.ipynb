# %%
# %matplotlib inline

import pandas as pd
vocab_path = '../data/goi/goi.csv'
edu_vocab = pd.read_csv(vocab_path, encoding='shift_jis')

# %%
edu_vocab
# Out:
#           No  標準的な表記      読み  語彙の難易度   品詞1                          品詞2(詳細)  \
# 0          4       あ       ア  2.初級後半    名詞                       名詞-普通名詞-一般
# 1          3       亜       ア  6.上級後半   接頭辞                       名詞-普通名詞-一般
# 2          5      ああ      アア  2.初級後半   感動詞                           感動詞-一般
# 3          6      ああ      アア  3.中級前半   感動詞                               副詞
# 4          7   アーケード   アーケード  4.中級後半    名詞                       名詞-普通名詞-一般
# 5          8     アーチ     アーチ  4.中級後半    名詞                       名詞-普通名詞-一般
# 6          9   アーチスト   アーチスト  3.中級前半    名詞                       名詞-普通名詞-一般
# 7         10     アート     アート  3.中級前半    名詞                       名詞-普通名詞-一般
# 8         11     アーム     アーム  5.上級前半    名詞                       名詞-普通名詞-一般
# 9         12   アーモンド   アーモンド  3.中級前半    名詞                       名詞-普通名詞-一般
# 10        14     アール     アール  6.上級後半    名詞                       名詞-普通名詞-一般
# 11        15       愛      アイ  2.初級後半    名詞                       名詞-普通名詞-一般
# 12        16    アイアン    アイアン  6.上級後半    名詞                       名詞-普通名詞-一般
# 13        17     愛煙家   アイエンカ  6.上級後半    名詞        名詞-普通名詞-一般 and 接尾辞-名詞的-一般
# 14        18      相方    アイカタ  6.上級後半    名詞                       名詞-普通名詞-一般
# 15     20003   相変わらず  アイカワラズ  5.上級前半    名詞            接頭辞 and 動詞-一般 and 助動詞
# 16        19      哀願    アイガン  6.上級後半    名詞                     名詞-普通名詞-サ変可能
# 17        20      ＩＱ   アイキュー  5.上級前半    名詞                       名詞-普通名詞-一般
# 18        22      愛敬   アイキョウ  6.上級後半    名詞                       名詞-普通名詞-一般
# 19        23      愛犬    アイケン  4.中級後半    名詞                       名詞-普通名詞-一般
# 20        24      愛護     アイゴ  5.上級前半    名詞                     名詞-普通名詞-サ変可能
# 21        25      愛好    アイコウ  5.上級前半    名詞                     名詞-普通名詞-サ変可能
# 22        26      愛国    アイコク  5.上級前半    名詞                       名詞-普通名詞-一般
# 23        27     愛国心  アイコクシン  4.中級後半    名詞        名詞-普通名詞-一般 and 接尾辞-名詞的-一般
# 24        28    合い言葉   アイコトバ  5.上級前半    名詞                       名詞-普通名詞-一般
# 25        29      挨拶    アイサツ  1.初級前半    名詞                     名詞-普通名詞-サ変可能
# 26        31      愛車    アイシャ  4.中級後半    名詞                       名詞-普通名詞-一般
# 27        32      哀愁   アイシュウ  5.上級前半    名詞                       名詞-普通名詞-一般
# 28        33      相性   アイショウ  4.中級後半    名詞                       名詞-普通名詞-一般
# 29        34      愛称   アイショウ  4.中級後半    名詞                       名詞-普通名詞-一般
# ...      ...     ...     ...     ...   ...                              ...
# 17890  19305      割に     ワリニ  4.中級後半    副詞          名詞-普通名詞-副詞可能 and 助詞-格助詞
# 17891  19306    割りばし    ワリバシ  3.中級前半    名詞                       名詞-普通名詞-一般
# 17892  20105      割引    ワリビキ  5.上級前半    名詞                     名詞-普通名詞-サ変可能
# 17893  19307    割り引く    ワリビク  4.中級後半  動詞1類                            動詞-一般
# 17894  19308      割安    ワリヤス  5.上級前半    名詞                           形状詞-一般
# 17895  19309      割る      ワル  3.中級前半  動詞1類                            動詞-一般
# 17896  19310       悪      ワル  4.中級後半    名詞                    名詞-普通名詞-形状詞可能
# 17897  19311      悪い     ワルイ  1.初級前半  イ形容詞                           形容詞-一般
# 17898  19312      悪気     ワルギ  5.上級前半    名詞                       名詞-普通名詞-一般
# 17899  19313      悪口    ワルクチ  4.中級後半    名詞                       名詞-普通名詞-一般
# 17900  19314     ワルツ     ワルツ  5.上級前半    名詞                       名詞-普通名詞-一般
# 17901  19315      悪者    ワルモノ  4.中級後半    名詞                       名詞-普通名詞-一般
# 17902  19316       我      ワレ  5.上級前半    名詞                              代名詞
# 17903  19317      割れ      ワレ  5.上級前半    名詞                       名詞-普通名詞-一般
# 17904  19318     我先に   ワレサキニ  5.上級前半  定型表現  代名詞 and 名詞-普通名詞-副詞可能 and 助詞-格助詞
# 17905  19320     割れ目     ワレメ  5.上級前半    名詞                       名詞-普通名詞-一般
# 17906  19321     割れ物    ワレモノ  4.中級後半    名詞                       名詞-普通名詞-一般
# 17907  19322     割れる     ワレル  3.中級前半  動詞2類                            動詞-一般
# 17908  19323      我々    ワレワレ  4.中級後半    名詞                              代名詞
# 17909  19325      ワン      ワン  3.中級前半   接頭辞                       名詞-普通名詞-一般
# 17910  19326       湾      ワン  4.中級後半    名詞                       名詞-普通名詞-一般
# 17911  19328      わん      ワン  4.中級後半    名詞                       名詞-普通名詞-一般
# 17912  19333   ワンタッチ   ワンタッチ  4.中級後半    名詞      名詞-普通名詞-一般 and 名詞-普通名詞-サ変可能
# 17913  19334   ワンダフル   ワンダフル  4.中級後半    名詞                    名詞-普通名詞-形状詞可能
# 17914  19335    ワンタン    ワンタン  5.上級前半    名詞                       名詞-普通名詞-一般
# 17915  19336  ワンパターン  ワンパターン  5.上級前半    名詞        名詞-普通名詞-一般 and 名詞-普通名詞-一般
# 17916  20121   ワンピース   ワンピース  2.初級後半    名詞                       名詞-普通名詞-一般
# 17917  19337    ワンマン    ワンマン  5.上級前半    名詞                           形状詞-一般
# 17918  19338      腕力   ワンリョク  5.上級前半    名詞                       名詞-普通名詞-一般
# 17919  19339    わんわん    ワンワン  4.中級後半    名詞                               副詞
#
#         語種
# 0       和語
# 1       漢語
# 2       和語
# 3       和語
# 4      外来語
# 5      外来語
# 6      外来語
# 7      外来語
# 8      外来語
# 9      外来語
# 10     外来語
# 11      漢語
# 12     外来語
# 13      漢語
# 14      和語
# 15      和語
# 16      漢語
# 17     外来語
# 18      漢語
# 19      漢語
# 20      漢語
# 21      漢語
# 22      漢語
# 23      漢語
# 24      和語
# 25      漢語
# 26      漢語
# 27      漢語
# 28     混種語
# 29      漢語
# ...    ...
# 17890   和語
# 17891   和語
# 17892   和語
# 17893   和語
# 17894   和語
# 17895   和語
# 17896   和語
# 17897   和語
# 17898  混種語
# 17899   和語
# 17900  外来語
# 17901   和語
# 17902   漢語
# 17903   和語
# 17904   和語
# 17905   和語
# 17906   和語
# 17907   和語
# 17908   和語
# 17909  外来語
# 17910   漢語
# 17911   漢語
# 17912  外来語
# 17913  外来語
# 17914  外来語
# 17915  外来語
# 17916  外来語
# 17917  外来語
# 17918   漢語
# 17919   和語
#
# [17920 rows x 7 columns]

# %%
edu_vocab[['標準的な表記', '語彙の難易度']]
# Out:
#        標準的な表記  語彙の難易度
# 0           あ  2.初級後半
# 1           亜  6.上級後半
# 2          ああ  2.初級後半
# 3          ああ  3.中級前半
# 4       アーケード  4.中級後半
# 5         アーチ  4.中級後半
# 6       アーチスト  3.中級前半
# 7         アート  3.中級前半
# 8         アーム  5.上級前半
# 9       アーモンド  3.中級前半
# 10        アール  6.上級後半
# 11          愛  2.初級後半
# 12       アイアン  6.上級後半
# 13        愛煙家  6.上級後半
# 14         相方  6.上級後半
# 15      相変わらず  5.上級前半
# 16         哀願  6.上級後半
# 17         ＩＱ  5.上級前半
# 18         愛敬  6.上級後半
# 19         愛犬  4.中級後半
# 20         愛護  5.上級前半
# 21         愛好  5.上級前半
# 22         愛国  5.上級前半
# 23        愛国心  4.中級後半
# 24       合い言葉  5.上級前半
# 25         挨拶  1.初級前半
# 26         愛車  4.中級後半
# 27         哀愁  5.上級前半
# 28         相性  4.中級後半
# 29         愛称  4.中級後半
# ...       ...     ...
# 17890      割に  4.中級後半
# 17891    割りばし  3.中級前半
# 17892      割引  5.上級前半
# 17893    割り引く  4.中級後半
# 17894      割安  5.上級前半
# 17895      割る  3.中級前半
# 17896       悪  4.中級後半
# 17897      悪い  1.初級前半
# 17898      悪気  5.上級前半
# 17899      悪口  4.中級後半
# 17900     ワルツ  5.上級前半
# 17901      悪者  4.中級後半
# 17902       我  5.上級前半
# 17903      割れ  5.上級前半
# 17904     我先に  5.上級前半
# 17905     割れ目  5.上級前半
# 17906     割れ物  4.中級後半
# 17907     割れる  3.中級前半
# 17908      我々  4.中級後半
# 17909      ワン  3.中級前半
# 17910       湾  4.中級後半
# 17911      わん  4.中級後半
# 17912   ワンタッチ  4.中級後半
# 17913   ワンダフル  4.中級後半
# 17914    ワンタン  5.上級前半
# 17915  ワンパターン  5.上級前半
# 17916   ワンピース  2.初級後半
# 17917    ワンマン  5.上級前半
# 17918      腕力  5.上級前半
# 17919    わんわん  4.中級後半
#
# [17920 rows x 2 columns]

# %%
edu_vocab['語彙の難易度'] = edu_vocab['語彙の難易度'].map(lambda s: s[0]).astype('int')
edu_vocab['語彙の難易度']
# Out:
# 0        2
# 1        6
# 2        2
# 3        3
# 4        4
# 5        4
# 6        3
# 7        3
# 8        5
# 9        3
# 10       6
# 11       2
# 12       6
# 13       6
# 14       6
# 15       5
# 16       6
# 17       5
# 18       6
# 19       4
# 20       5
# 21       5
# 22       5
# 23       4
# 24       5
# 25       1
# 26       4
# 27       5
# 28       4
# 29       4
#         ..
# 17890    4
# 17891    3
# 17892    5
# 17893    4
# 17894    5
# 17895    3
# 17896    4
# 17897    1
# 17898    5
# 17899    4
# 17900    5
# 17901    4
# 17902    5
# 17903    5
# 17904    5
# 17905    5
# 17906    4
# 17907    3
# 17908    4
# 17909    3
# 17910    4
# 17911    4
# 17912    4
# 17913    4
# 17914    5
# 17915    5
# 17916    2
# 17917    5
# 17918    5
# 17919    4
# Name: 語彙の難易度, Length: 17920, dtype: int64

# %%
edu_vocab.dtypes
# Out:
# No          int64
# 標準的な表記     object
# 読み         object
# 語彙の難易度      int64
# 品詞1        object
# 品詞2(詳細)    object
# 語種         object
# dtype: object

# %%
edu_vocab[edu_vocab['標準的な表記'] == '天気']['語彙の難易度']
# Out:
# 11276    2
# Name: 語彙の難易度, dtype: int64
